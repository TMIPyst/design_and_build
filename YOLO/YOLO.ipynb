# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !pip install ultralytics
# !cp -r ./gdrive/MyDrive/Colab-Notebooks/MakePT/datasets datasets
# Out:
# Mounted at /content/gdrive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 13.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.environ['LC_ALL'] = 'en_US.UTF-8'
# !cp -r '/content/runs' '/content/gdrive/MyDrive/runs'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-15-95db31524071> in <cell line: 5>()
#       3 import os
#       4 os.environ['LC_ALL'] = 'en_US.UTF-8'
# ----> 5 get_ipython().system("cp -r '/content/runs' '/content/gdrive/MyDrive/runs'")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
# ...

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("best.pt")  # load a pretrained model (recommended for training)
#model.train(data="./train.yaml", epochs=300, workers=0, patience=25)  # train the model, workers=0 if windows

# Resume training
model = YOLO('/content/datasets/datasets/last.pt')  # load a partially trained model
model.train(data="/content/datasets/datasets/train.yaml", epochs=300, workers=0, resume=True, patience=25)  # train the model,workers=0 if windows

metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
